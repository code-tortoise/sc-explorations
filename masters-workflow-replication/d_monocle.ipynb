# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
install.packages("BiocManager")
BiocManager::install(version = "3.14")
# Out:
#   There is a binary version available but the source version is later:
#              binary  source needs_compilation
# BiocManager 1.30.15 1.30.20             FALSE
# installing the source package 'BiocManager'
# Error: Bioconductor version '3.14' requires R version '4.1'; use
#   `BiocManager::install(version = '3.10')` with R version 3.6; see
#   https://bioconductor.org/install
# Traceback:
#
# 1. BiocManager::install(version = "3.14")
# 2. .version_validate(version)
# 3. ifelse(.is_CRAN_check(), .message(txt), .stop(txt))
# 4. .stop(txt)
# 5. stop(.msg(...), call. = call.)

# %%
*This whole issue of anaconda navigator and R seems to be fraught  with issues, this current one is that the R version of anaconda navigator is out of date 
I am just going to use RStudio with renv to see if that is less time consuming*
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:1: unexpected '*'
# 1: *
#     ^
# Traceback:

# %%
BiocManager::install(c('BiocGenerics', 'DelayedArray', 'DelayedMatrixStats',
                       'limma', 'lme4', 'S4Vectors', 'SingleCellExperiment',
                       'SummarizedExperiment', 'batchelor', 'HDF5Array',
                       'terra', 'ggrastr'))
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected symbol
# 1: conda list
#           ^
# Traceback:
